# %% [markdown]
# ## Data Collection

# %%
# %pip install pynput
# %pip install screeninfo
# Out:
# Collecting pynput
#   Using cached pynput-1.7.7-py2.py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: six in /Users/jangsus1/.env/lib/python3.11/site-packages (from pynput) (1.16.0)
# Collecting pyobjc-framework-ApplicationServices>=8.0 (from pynput)
#   Using cached pyobjc_framework_ApplicationServices-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-Quartz>=8.0 (from pynput)
#   Using cached pyobjc_framework_Quartz-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting pyobjc-core>=10.3.1 (from pyobjc-framework-ApplicationServices>=8.0->pynput)
#   Using cached pyobjc_core-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Cocoa>=10.3.1 (from pyobjc-framework-ApplicationServices>=8.0->pynput)
#   Using cached pyobjc_framework_Cocoa-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreText>=10.3.1 (from pyobjc-framework-ApplicationServices>=8.0->pynput)
#   Using cached pyobjc_framework_CoreText-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Using cached pynput-1.7.7-py2.py3-none-any.whl (90 kB)
# Using cached pyobjc_framework_ApplicationServices-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (31 kB)
# Using cached pyobjc_framework_Quartz-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (227 kB)
# Using cached pyobjc_core-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (775 kB)
# Using cached pyobjc_framework_Cocoa-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (396 kB)
# Using cached pyobjc_framework_CoreText-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (30 kB)
# Installing collected packages: pyobjc-core, pyobjc-framework-Cocoa, pyobjc-framework-Quartz, pyobjc-framework-CoreText, pyobjc-framework-ApplicationServices, pynput
# Successfully installed pynput-1.7.7 pyobjc-core-10.3.1 pyobjc-framework-ApplicationServices-10.3.1 pyobjc-framework-Cocoa-10.3.1 pyobjc-framework-CoreText-10.3.1 pyobjc-framework-Quartz-10.3.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting screeninfo
#   Using cached screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting Cython (from screeninfo)
#   Using cached Cython-3.0.11-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Users/jangsus1/.env/lib/python3.11/site-packages (from screeninfo) (10.3.1)
# Requirement already satisfied: pyobjc-core>=10.3.1 in /Users/jangsus1/.env/lib/python3.11/site-packages (from pyobjc-framework-Cocoa->screeninfo) (10.3.1)
# Using cached screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Using cached Cython-3.0.11-py2.py3-none-any.whl (1.2 MB)
# Installing collected packages: Cython, screeninfo
# Successfully installed Cython-3.0.11 screeninfo-0.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from pynput import mouse
import threading
import time
from screeninfo import get_monitors
from glob import glob

ACTION = "designing"
TIME = 5  # in minutes

# Get monitor information
monitors = get_monitors()
for monitor in monitors:
    print(f"  Dimensions: {monitor.width}x{monitor.height}")
    print(f"  Position: ({monitor.x}, {monitor.y})\n")

count = len(glob(f"recordings/{ACTION}_mouse_events*.txt"))
filename = f"recordings/{ACTION}_mouse_events_{count}.txt"

with open(filename, "w") as f:
    for id, monitor in enumerate(monitors):
        f.write(str((id, monitor.width, monitor.height, monitor.x, monitor.y)) + "\n")

# List to store mouse events
event_list = []
# Lock to synchronize access to event_list
lock = threading.Lock()
# Global listener variable
listener = None

def get_monitor_for_position(x, y):
    for idx, monitor in enumerate(monitors):
        if (monitor.x <= x < monitor.x + monitor.width and
            monitor.y <= y < monitor.y + monitor.height):
            return idx
    return None  # If position is not within any monitor

def adjust_coordinates(x, y):
    monitor_idx = get_monitor_for_position(x, y)
    if monitor_idx is None:
        return x, y
    monitor = monitors[monitor_idx]
    x_adj = x - monitor.x
    y_adj = y - monitor.y
    if monitor_idx != 0:
        x_adj = x_adj % monitors[0].width
        y_adj = y_adj % monitors[0].height
    return x_adj, y_adj

def on_move(x, y):
    x_adj, y_adj = adjust_coordinates(x, y)
    with lock:
        event_list.append(("move", time.time(), x_adj, y_adj))

def on_click(x, y, button, pressed):
    x_adj, y_adj = adjust_coordinates(x, y)
    with lock:
        event_list.append(("click", time.time(), x_adj, y_adj, button.name, pressed))

def on_scroll(x, y, dx, dy):
    x_adj, y_adj = adjust_coordinates(x, y)
    with lock:
        event_list.append(("scroll", time.time(), x_adj, y_adj, dx, dy))

def flush_events():
    global listener
    interval = 0.5
    elapsed = 0
    while True:
        time.sleep(interval)
        elapsed += interval
        with lock:
            if event_list:
                # Write events to file
                with open(filename, "a") as f:
                    for event in event_list:
                        f.write(str(event) + "\n")
                event_list.clear()
        # print minutes, seconds remaining
        remain = int(TIME * 60 - elapsed)
        minutes = remain // 60
        seconds = remain % 60
        print(f"\r{minutes:02}:{seconds:02}", end="")
        if listener is not None and not listener.running:
            break

# Start the mouse listener and the flushing thread
def main():
    global listener
    flush_thread = threading.Thread(target=flush_events)
    flush_thread.daemon = True
    flush_thread.start()

    total = TIME * 60  # total seconds

    with mouse.Listener(
        on_move=on_move, on_click=on_click, on_scroll=on_scroll
    ) as listener:
        # Start timer to stop the listener after total seconds
        timer = threading.Timer(total, listener.stop)
        timer.start()
        listener.join()

    # After listener stops, flush any remaining events
    with lock:
        if event_list:
            with open(filename, "a") as f:
                for event in event_list:
                    f.write(str(event) + "\n")
            event_list.clear()
    print("\nRecording finished.")

if __name__ == "__main__":
    # Count down 3 seconds
    print("Recording starts in 3 seconds...")
    for i in range(3, 0, -1):
        print(i)
        time.sleep(1)
    print("Recording started.")
    main()
# Out:
#   Dimensions: 1728x1117
#   Position: (0, 0)
#
# Recording starts in 3 seconds...
# 3
# 2
# 1
# Recording started.
# 04:59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 119
#     117     time.sleep(1)
#     118 print("Recording started.")
# --> 119 main()
#
# Cell In[3], line 101, in main()
#      99     timer = threading.Timer(total, listener.stop)
#     100     timer.start()
# --> 101     listener.join()
#     103 # After listener stops, flush any remaining events
#     104 with lock:
#
# File ~/.env/lib/python3.11/site-packages/pynput/_util/__init__.py:271, in AbstractListener.join(self, timeout, *args)
#     269 def join(self, timeout=None, *args):
#     270     start = time.time()
# --> 271     super(AbstractListener, self).join(timeout, *args)
#     272     timeout = max(0.0, timeout - (time.time() - start)) \
#     273         if timeout is not None \
#     274         else None
#     276     # Reraise any exceptions; make sure not to block if a timeout was
#     277     # provided
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:
# 04:59
